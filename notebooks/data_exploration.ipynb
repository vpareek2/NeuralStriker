# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from IPython.display import display

# %%
df_2022 = pd.read_csv('../data/final/2022.csv').drop(columns=['Unnamed: 0'])
df_2023 = pd.read_csv('../data/final/2023.csv').drop(columns=['Unnamed: 0'])

# %%
dataframes = [df_2022, df_2022]
for df in dataframes:
    display(df.head(3))
# Out:
#    player_id             Player Nation Pos    Squad     Comp  Age   Gls   Ast  \
# 0       1000  Salis Abdul Samed    GHA  MF     Lens  Ligue 1   22  0.03  0.03
# 1       1001   Francesco Acerbi    ITA  DF    Inter  Serie A   34  0.00  0.07
# 2       1002       Marcos Acuña    ARG  DF  Sevilla  La Liga   30  0.14  0.09
#
#     G+A  G-PK  G+A-PK    xG   xAG  xG+xAG  npxG  npxG+xAG
# 0  0.06  0.03    0.06  0.03  0.05    0.08  0.03      0.08
# 1  0.07  0.00    0.07  0.04  0.04    0.08  0.04      0.08
# 2  0.24  0.14    0.24  0.05  0.20    0.26  0.05      0.26
#    player_id             Player Nation Pos    Squad     Comp  Age   Gls   Ast  \
# 0       1000  Salis Abdul Samed    GHA  MF     Lens  Ligue 1   22  0.03  0.03
# 1       1001   Francesco Acerbi    ITA  DF    Inter  Serie A   34  0.00  0.07
# 2       1002       Marcos Acuña    ARG  DF  Sevilla  La Liga   30  0.14  0.09
#
#     G+A  G-PK  G+A-PK    xG   xAG  xG+xAG  npxG  npxG+xAG
# ...

# %%
df_2022.describe()
# Out:
#          player_id         Age         Gls         Ast         G+A  \
# count   926.000000  926.000000  926.000000  926.000000  926.000000
# mean   1478.601512   25.118790    0.094571    0.085856    0.180583
# std     286.359000    4.766202    0.185992    0.385659    0.450897
# min    1000.000000   14.000000    0.000000    0.000000    0.000000
# 25%    1232.250000   22.000000    0.000000    0.000000    0.000000
# 50%    1463.500000   25.000000    0.012143    0.012857    0.050000
# 75%    1724.750000   28.000000    0.095000    0.083214    0.199286
# max    1989.000000   40.000000    1.330000   10.000000   10.000000
#
#              G-PK      G+A-PK          xG         xAG      xG+xAG        npxG  \
# count  926.000000  926.000000  926.000000  926.000000  926.000000  926.000000
# mean     0.088331    0.174334    0.111316    0.075338    0.186591    0.104446
# std      0.175594    0.445859    0.235563    0.120466    0.293524    0.227685
# ...

# %%
df_2023.describe()
# Out:
#          player_id         Age         Gls         Ast         G+A  \
# count   735.000000  735.000000  735.000000  735.000000  735.000000
# mean   1378.677551   25.730612    0.104647    0.107673    0.212344
# std     226.608819    4.484102    0.249388    0.717229    0.766313
# min    1000.000000   16.000000    0.000000    0.000000    0.000000
# 25%    1183.500000   22.000000    0.000000    0.000000    0.000000
# 50%    1368.000000   25.000000    0.000000    0.000000    0.000000
# 75%    1572.500000   29.000000    0.055714    0.037143    0.192143
# max    1782.000000   40.000000    1.850000   18.000000   18.000000
#
#              G-PK      G+A-PK          xG         xAG      xG+xAG        npxG  \
# count  735.000000  735.000000  735.000000  735.000000  735.000000  735.000000
# mean     0.097283    0.204980    0.107259    0.091642    0.198877    0.100319
# std      0.233942    0.760208    0.218918    0.401805    0.464917    0.206571
# ...

# %%
sns.histplot(df_2022['Gls'], kde=True)
plt.title('Histogram of Goals Scored per 90 minutes in 2022') 
plt.xlabel('Goals')
plt.ylabel('Count')

plt.show()

# %%
sns.histplot(df_2023['Gls'], kde=True, bins=45)
plt.title('Histogram of Goals Scored per 90 minutes in 2023') 
plt.xlabel('Goals')
plt.ylabel('Count')

plt.show()

# %%
plt.scatter(df_2023['Gls'], df_2023['xG'])
plt.xlabel('Goals')
plt.ylabel('xG')
plt.title('Goals vs Expected Goals in 2023')
plt.show()

# %%
plt.scatter(df_2022['Gls'], df_2022['xG'])
plt.xlabel('Goals')
plt.ylabel('xG')
plt.title('Goals vs Expected Goals in 2022')
plt.show()

# Big outliers.

# %%
numeric_columns2022 = df_2022.select_dtypes(include=[np.number])
numeric_columns2023 = df_2023.select_dtypes(include=[np.number])

correlation_matrix2022 = numeric_columns2022.corr()
correlation_matrix2023 = numeric_columns2023.corr()

# %%
plt.figure(figsize=(7, 3))  # Can adjust the size as necessary
sns.heatmap(correlation_matrix2022, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap 2022')
plt.show()

# %%
plt.figure(figsize=(7, 3))  # Can adjust the size as necessary
sns.heatmap(correlation_matrix2023, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap 2023')
plt.show()
